# %%
import csv
import pandas as pd
dados = pd.read_csv("funcionarios.csv",delimiter=';')

# %%
df2 = dados[0:10]
df2.pop('Meses')
# Out:
# 0     3
# 1    10
# 2     5
# 3    10
# 4     7
# 5     0
# 6     0
# 7     4
# 8    10
# 9     6
# Name: Meses, dtype: int64

# %% [markdown]
# df2

# %%
df2.fillna('Sem')
# Out:
#    Funcionario Est.civil    Inst Filhos  Salario  Anos    Regiao
# 0            1  solteiro  1oGrau    Sem     4.00    26  interior
# 1            2    casado  1oGrau      1     4.56    32   capital
# 2            3    casado  1oGrau      2     5.25    36   capital
# 3            4  solteiro  2oGrau    Sem     5.73    20     outro
# 4            5  solteiro  1oGrau    Sem     6.26    40     outro
# 5            6    casado  1oGrau      0     6.66    28  interior
# 6            7  solteiro  1oGrau    Sem     6.86    41  interior
# 7            8  solteiro  1oGrau    Sem     7.39    43   capital
# 8            9    casado  2oGrau      1     7.59    34   capital
# 9           10  solteiro  2oGrau    Sem     7.44    23     outro

# %%
df3 = df2[['Filhos','Salario']]

# %%
df3
# Out:
#    Filhos  Salario
# 0     NaN     4.00
# 1     1.0     4.56
# 2     2.0     5.25
# 3     NaN     5.73
# 4     NaN     6.26
# 5     0.0     6.66
# 6     NaN     6.86
# 7     NaN     7.39
# 8     1.0     7.59
# 9     NaN     7.44

# %%
df4 = df2[['Funcionario','Regiao']]

# %% [markdown]
# df4

# %%
df4[0:5]
# Out:
#    Funcionario    Regiao
# 0            1  interior
# 1            2   capital
# 2            3   capital
# 3            4     outro
# 4            5     outro

# %%
df3 = dados
df3['salario_100'] = dados['Salario']*100
df3
# Out:
#     Funcionario Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao  \
# 0             1  solteiro    1oGrau     NaN     4.00    26      3  interior
# 1             2    casado    1oGrau     1.0     4.56    32     10   capital
# 2             3    casado    1oGrau     2.0     5.25    36      5   capital
# 3             4  solteiro    2oGrau     NaN     5.73    20     10     outro
# 4             5  solteiro    1oGrau     NaN     6.26    40      7     outro
# 5             6    casado    1oGrau     0.0     6.66    28      0  interior
# 6             7  solteiro    1oGrau     NaN     6.86    41      0  interior
# 7             8  solteiro    1oGrau     NaN     7.39    43      4   capital
# 8             9    casado    2oGrau     1.0     7.59    34     10   capital
# 9            10  solteiro    2oGrau     NaN     7.44    23      6     outro
# 10           11    casado    2oGrau     2.0     8.12    33      6  interior
# ...

# %%
df = dados
df[df['Regiao'] == 'interior']
# Out:
#     Funcionario Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao  \
# 0             1  solteiro    1oGrau     NaN     4.00    26      3  interior
# 5             6    casado    1oGrau     0.0     6.66    28      0  interior
# 6             7  solteiro    1oGrau     NaN     6.86    41      0  interior
# 10           11    casado    2oGrau     2.0     8.12    33      6  interior
# 14           15    casado    2oGrau     0.0     9.13    30      5  interior
# 18           19  solteiro  Superior     NaN    10.53    25      8  interior
# 19           20  solteiro    2oGrau     NaN    10.76    37      4  interior
# 24           25    casado    2oGrau     2.0    13.23    32      5  interior
# 27           28    casado    2oGrau     0.0    14.69    29      8  interior
# 28           29    casado    2oGrau     5.0    14.71    40      6  interior
# 31           32    casado    2oGrau     1.0    16.61    36      4  interior
# ...

# %%
dados[(dados['Est.civil'] == 'solteiro') & (dados['Regiao']=='interior')]
# Out:
#     Funcionario Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao  \
# 0             1  solteiro    1oGrau     NaN     4.00    26      3  interior
# 6             7  solteiro    1oGrau     NaN     6.86    41      0  interior
# 18           19  solteiro  Superior     NaN    10.53    25      8  interior
# 19           20  solteiro    2oGrau     NaN    10.76    37      4  interior
#
#     salario_100
# 0         400.0
# 6         686.0
# 18       1053.0
# 19       1076.0

# %%
dados[(dados['Anos']>30)]
# Out:
#     Funcionario Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao  \
# 1             2    casado    1oGrau     1.0     4.56    32     10   capital
# 2             3    casado    1oGrau     2.0     5.25    36      5   capital
# 4             5  solteiro    1oGrau     NaN     6.26    40      7     outro
# 6             7  solteiro    1oGrau     NaN     6.86    41      0  interior
# 7             8  solteiro    1oGrau     NaN     7.39    43      4   capital
# 8             9    casado    2oGrau     1.0     7.59    34     10   capital
# 10           11    casado    2oGrau     2.0     8.12    33      6  interior
# 12           13  solteiro    2oGrau     NaN     8.74    37      5     outro
# 13           14    casado    1oGrau     3.0     8.95    44      2     outro
# 15           16  solteiro    2oGrau     NaN     9.35    38      8     outro
# 16           17    casado    2oGrau     1.0     9.77    31      7   capital
# ...

# %%
    import pandas as pd
    df1 = pd.DataFrame({'id':[1,2,3,4,5], 'nome':['Pedro','Joao','Ana','Maria','Ivo']})
    df2 = pd.DataFrame({'id':[1,2,3,4,5],'idade':[29,43,21,32,63]})
    df3 = pd.merge(df1,df2, on='id')

# %%
df3
# Out:
#    id   nome  idade
# 0   1  Pedro     29
# 1   2   Joao     43
# 2   3    Ana     21
# 3   4  Maria     32
# 4   5    Ivo     63

# %%
df
# Out:
#     Funcionario Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao  \
# 0             1  solteiro    1oGrau     NaN     4.00    26      3  interior
# 1             2    casado    1oGrau     1.0     4.56    32     10   capital
# 2             3    casado    1oGrau     2.0     5.25    36      5   capital
# 3             4  solteiro    2oGrau     NaN     5.73    20     10     outro
# 4             5  solteiro    1oGrau     NaN     6.26    40      7     outro
# 5             6    casado    1oGrau     0.0     6.66    28      0  interior
# 6             7  solteiro    1oGrau     NaN     6.86    41      0  interior
# 7             8  solteiro    1oGrau     NaN     7.39    43      4   capital
# 8             9    casado    2oGrau     1.0     7.59    34     10   capital
# 9            10  solteiro    2oGrau     NaN     7.44    23      6     outro
# 10           11    casado    2oGrau     2.0     8.12    33      6  interior
# ...

# %%
def maiuscula(X):
        return x.upper()

# %%
df = dados
df['Regiao'].apply(lambda x:x.upper())
# Out:
# 0     INTERIOR
# 1      CAPITAL
# 2      CAPITAL
# 3        OUTRO
# 4        OUTRO
# 5     INTERIOR
# 6     INTERIOR
# 7      CAPITAL
# 8      CAPITAL
# 9        OUTRO
# 10    INTERIOR
# 11     CAPITAL
# 12       OUTRO
# 13       OUTRO
# 14    INTERIOR
# 15       OUTRO
# 16     CAPITAL
# 17       OUTRO
# 18    INTERIOR
# 19    INTERIOR
# 20       OUTRO
# 21     CAPITAL
# 22       OUTRO
# 23       OUTRO
# 24    INTERIOR
# 25       OUTRO
# 26       OUTRO
# 27    INTERIOR
# 28    INTERIOR
# 29     CAPITAL
# 30       OUTRO
# 31    INTERIOR
# 32     CAPITAL
# 33     CAPITAL
# 34     CAPITAL
# 35    INTERIOR
# Name: Regiao, dtype: object

# %%
df
# Out:
#     Funcionario Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao
# 0             1  solteiro    1oGrau     NaN     4.00    26      3  interior
# 1             2    casado    1oGrau     1.0     4.56    32     10   capital
# 2             3    casado    1oGrau     2.0     5.25    36      5   capital
# 3             4  solteiro    2oGrau     NaN     5.73    20     10     outro
# 4             5  solteiro    1oGrau     NaN     6.26    40      7     outro
# 5             6    casado    1oGrau     0.0     6.66    28      0  interior
# 6             7  solteiro    1oGrau     NaN     6.86    41      0  interior
# 7             8  solteiro    1oGrau     NaN     7.39    43      4   capital
# 8             9    casado    2oGrau     1.0     7.59    34     10   capital
# 9            10  solteiro    2oGrau     NaN     7.44    23      6     outro
# 10           11    casado    2oGrau     2.0     8.12    33      6  interior
# ...

# %%
import csv
import pandas as pd
idh = pd.read_csv("cidades_idh.csv",delimiter=';')
nomes = pd.read_csv("cidades_nomes.csv",delimiter=';')
df3 = pd.merge(idh, nomes, on='id')
df3[(df3['UF']== ' Sao Paulo')]
# Out:
#       id    # IDHM (2010)                 Municipio          UF
# 0      1    1       0,862        Sao Caetano do Sul   Sao Paulo
# 1      2    2       0,854        Aguas de Sao Pedro   Sao Paulo
# 5      6    6        0,84                    Santos   Sao Paulo
# 10    11   11       0,822                   Jundiai   Sao Paulo
# 11    12   12       0,819                  Valinhos   Sao Paulo
# 12    13   13       0,817                   Vinhedo   Sao Paulo
# 13    14   14       0,815               Santo Andre   Sao Paulo
# 14    15   15       0,815                Araraquara   Sao Paulo
# 15    16   16       0,814       Santana de Parnaiba   Sao Paulo
# 17    18   18       0,812             Ilha Solteira   Sao Paulo
# 18    19   19       0,811                 Americana   Sao Paulo
# 23    24   24       0,807       Sao Jose dos Campos   Sao Paulo
# 25    26   25       0,806       Presidente Prudente   Sao Paulo
# 27    28   28       0,805                 Sao Paulo   Sao Paulo
# ...

# %%
df3
# Out:
#       id    # IDHM (2010)                 Municipio                   UF
# 0      1    1       0,862        Sao Caetano do Sul            Sao Paulo
# 1      2    2       0,854        Aguas de Sao Pedro            Sao Paulo
# 2      3    3       0,847             Florianopolis       Santa Catarina
# 3      4    4       0,845        Balneario Camboriu       Santa Catarina
# 4      5    5       0,845                   Vitoria       Espirito Santo
# 5      6    6        0,84                    Santos            Sao Paulo
# 6      7    7       0,837                   Niteroi       Rio de Janeiro
# 7      8    8       0,827                   Joacaba       Santa Catarina
# 8      9    9       0,824                  Brasilia     Distrito Federal
# 9     10   10       0,823                  Curitiba               Parana
# 10    11   11       0,822                   Jundiai            Sao Paulo
# 11    12   12       0,819                  Valinhos            Sao Paulo
# ...

# %%
nomes
# Out:
#       id    # IDHM (2010)
# 0      1    1       0,862
# 1      2    2       0,854
# 2      3    3       0,847
# 3      4    4       0,845
# 4      5    5       0,845
# 5      6    6        0,84
# 6      7    7       0,837
# 7      8    8       0,827
# 8      9    9       0,824
# 9     10   10       0,823
# 10    11   11       0,822
# 11    12   12       0,819
# 12    13   13       0,817
# 13    14   14       0,815
# 14    15   15       0,815
# 15    16   16       0,814
# 16    17   17       0,813
# 17    18   18       0,812
# 18    19   19       0,811
# 19    20   20        0,81
# 20    21   21       0,809
# 21    22   21       0,809
# 22    23   23       0,808
# 23    24   24       0,807
# 24    25   25       0,806
# 25    26   25       0,806
# 26    27   25       0,806
# 27    28   28       0,805
# 28    29   28       0,805
# 29    30   28       0,805
# ..   ...  ...         ...
# 79    80   76       0,788
# 80    81   76       0,788
# 81    82   76       0,788
# ...

# %%
df = dados
df['Regiao'].apply(
    lambda x: 
        x.upper())
# Out:
# 0     INTERIOR
# 1      CAPITAL
# 2      CAPITAL
# 3        OUTRO
# 4        OUTRO
# 5     INTERIOR
# 6     INTERIOR
# 7      CAPITAL
# 8      CAPITAL
# 9        OUTRO
# 10    INTERIOR
# 11     CAPITAL
# 12       OUTRO
# 13       OUTRO
# 14    INTERIOR
# 15       OUTRO
# 16     CAPITAL
# 17       OUTRO
# 18    INTERIOR
# 19    INTERIOR
# 20       OUTRO
# 21     CAPITAL
# 22       OUTRO
# 23       OUTRO
# 24    INTERIOR
# 25       OUTRO
# 26       OUTRO
# 27    INTERIOR
# 28    INTERIOR
# 29     CAPITAL
# 30       OUTRO
# 31    INTERIOR
# 32     CAPITAL
# 33     CAPITAL
# 34     CAPITAL
# 35    INTERIOR
# Name: Regiao, dtype: object

# %%
df['Reg-Int']=df.apply(
    lambda row: 
        row['Regiao']+row['Inst'], axis=1)

# %%
df
# Out:
#     Funcionario Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao  \
# 0             1  solteiro    1oGrau     NaN     4.00    26      3  interior
# 1             2    casado    1oGrau     1.0     4.56    32     10   capital
# 2             3    casado    1oGrau     2.0     5.25    36      5   capital
# 3             4  solteiro    2oGrau     NaN     5.73    20     10     outro
# 4             5  solteiro    1oGrau     NaN     6.26    40      7     outro
# 5             6    casado    1oGrau     0.0     6.66    28      0  interior
# 6             7  solteiro    1oGrau     NaN     6.86    41      0  interior
# 7             8  solteiro    1oGrau     NaN     7.39    43      4   capital
# 8             9    casado    2oGrau     1.0     7.59    34     10   capital
# 9            10  solteiro    2oGrau     NaN     7.44    23      6     outro
# 10           11    casado    2oGrau     2.0     8.12    33      6  interior
# ...

# %%
def convert_int(linha):
    if linha['Inst']=='1oGrau':
        return 'Fundamental'
    elif linha ['Inst']=='2oGrau':
        return 'Medio'
df['Inst']=df.apply(convert_int,axis=1)

# %%
df
# Out:
#     Funcionario Est.civil         Inst  Filhos  Salario  Anos  Meses  \
# 0             1  solteiro  Fundamental     NaN     4.00    26      3
# 1             2    casado  Fundamental     1.0     4.56    32     10
# 2             3    casado  Fundamental     2.0     5.25    36      5
# 3             4  solteiro        Medio     NaN     5.73    20     10
# 4             5  solteiro  Fundamental     NaN     6.26    40      7
# 5             6    casado  Fundamental     0.0     6.66    28      0
# 6             7  solteiro  Fundamental     NaN     6.86    41      0
# 7             8  solteiro  Fundamental     NaN     7.39    43      4
# 8             9    casado        Medio     1.0     7.59    34     10
# 9            10  solteiro        Medio     NaN     7.44    23      6
# 10           11    casado        Medio     2.0     8.12    33      6
# 11           12  solteiro  Fundamental     NaN     8.46    27     11
# 12           13  solteiro        Medio     NaN     8.74    37      5
# ...
